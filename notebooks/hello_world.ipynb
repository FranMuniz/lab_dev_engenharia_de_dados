# %% [markdown]
# ### Hello World - 1º programa Spark

# %%
import time
time.sleep(10)  # espera 10 segundos

# %%
from pyspark.sql import SparkSession

# %%
spark = (
    SparkSession.builder
    .appName("Jupyter-Spark-Local")
    .master("local[*]") 
    .getOrCreate()
)

# %%
data = [('Hello',), ('World',)]
df = spark.createDataFrame(data, ['message'])

# %%
df.show()
# Out:
# +-------+
# |message|
# +-------+
# |  Hello|
# |  World|
# +-------+

# %%
# spark.stop()
